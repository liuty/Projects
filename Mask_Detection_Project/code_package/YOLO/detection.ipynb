# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/My\ Drive/Gatech/CS6220\ Project
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Gatech/CS6220 Project
# CS6220_Face_Mask_Detection_Proposal.gdoc  maskdata	  yolov5
# gatech_financial_certification_form1.pdf  plt.ipynb
# GenInput.ipynb				  RunYOLO3.ipynb

# %%
# %cd yolov5
# Out:
# /content/drive/My Drive/Gatech/CS6220 Project/yolov5

# %%
import time
start_time = time.time()
# !python detect.py --source data/mask_images --weights runs/train/exp12/weights/best.pt
elapse_time = time.time() - start_time
elapse_time
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/mask_images', update=False, view_img=False, weights=['runs/train/exp12/weights/best.pt'])
# Using torch 1.7.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7251912 parameters, 0 gradients
# image 1/853 /content/drive/My Drive/Gatech/CS6220 Project/yolov5/data/mask_images/maksssksksss0.png: 480x640 1 with_masks, 2 without_masks, Done. (0.476s)
# image 2/853 /content/drive/My Drive/Gatech/CS6220 Project/yolov5/data/mask_images/maksssksksss1.png: 256x640 7 with_masks, 1 without_masks, Done. (0.206s)
# image 3/853 /content/drive/My Drive/Gatech/CS6220 Project/yolov5/data/mask_images/maksssksksss10.png: 640x512 1 with_masks, Done. (0.454s)
# ...

# %%
print(elapse_time / 853)
print(elapse_time / 4072) # there are 4072 objects in total
# Out:
# 1.3084971231145288
# 0.2741031547192272

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp12')  # plot results.txt as results.png
